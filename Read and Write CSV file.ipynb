# %%
import pandas as pd

# %%
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv')
Data
# Out:
#    Order ID  Order Date CustomerName             State                City
# 0   B-26055  10-03-2018    Harivansh     Uttar Pradesh             Mathura
# 1   B-25993  03-02-2018       Madhav             Delhi               Delhi
# 2       NaN  24-01-2018  Madan Mohan     Uttar Pradesh             Mathura
# 3       NaN  27-12-2018        Gopal       Maharashtra              Mumbai
# 4   B-25757  21-08-2018     Vishakha    Madhya Pradesh              Indore
# 5   B-25967  21-01-2018       Sudevi     Uttar Pradesh                 NaN
# 6   B-25955  16-01-2018        Shiva       Maharashtra                Pune
# 7   B-26093  27-03-2018       Sarita       Maharashtra                Pune
# 8   B-25798  01-10-2018       Shishu    Andhra Pradesh           Hyderabad
# 9   B-25602  01-04-2018          NaN       Maharashtra                Pune
# 10  B-25858  13-11-2018          NaN       Maharashtra              Mumbai
# ...

# %%
# How to know all the columns name
Data.columns
# Out:
# Index(['Order ID', 'Order Date', 'CustomerName', 'State', 'City'], dtype='object')

# %%
#How to read some specific rows of the dataset
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv', nrows = 1)
Data
# Out:
#   Order ID  Order Date CustomerName          State     City
# 0  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura

# %%
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv', nrows = 6)
Data
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2      NaN  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3      NaN  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore
# 5  B-25967  21-01-2018       Sudevi   Uttar Pradesh      NaN

# %%
#How to read some specific columns of the dataset
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv', usecols = [2,3])
Data
# Out:
#    CustomerName             State
# 0     Harivansh     Uttar Pradesh
# 1        Madhav             Delhi
# 2   Madan Mohan     Uttar Pradesh
# 3         Gopal       Maharashtra
# 4      Vishakha    Madhya Pradesh
# 5        Sudevi     Uttar Pradesh
# 6         Shiva       Maharashtra
# 7        Sarita       Maharashtra
# 8        Shishu    Andhra Pradesh
# 9           NaN       Maharashtra
# 10          NaN       Maharashtra
# 11          NaN           Gujarat
# 12       Bhishm       Maharashtra
# 13       Yogesh       Maharashtra
# 14       Lalita     Uttar Pradesh
# 15       Madhav     Uttar Pradesh
# 16     Vishakha     Uttar Pradesh
# 17          NaN       Maharashtra
# 18       Gaurav           Gujarat
# 19         Amol             Bihar
# 20       Aastha  Himachal Pradesh
# 21  Madan Mohan     Uttar Pradesh
# 22        Pooja  Himachal Pradesh
# 23    Shrichand            Punjab
# 24       Hitesh    Madhya Pradesh
# 25      Shourya           Kerala
# ...

# %%
#How to Skip some specific rows of the dataset
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv', skiprows = [2,3])
Data
# Out:
#    Order ID  Order Date CustomerName             State                City
# 0   B-26055  10-03-2018    Harivansh     Uttar Pradesh             Mathura
# 1       NaN  27-12-2018        Gopal       Maharashtra              Mumbai
# 2   B-25757  21-08-2018     Vishakha    Madhya Pradesh              Indore
# 3   B-25967  21-01-2018       Sudevi     Uttar Pradesh                 NaN
# 4   B-25955  16-01-2018        Shiva       Maharashtra                Pune
# 5   B-26093  27-03-2018       Sarita       Maharashtra                Pune
# 6   B-25798  01-10-2018       Shishu    Andhra Pradesh           Hyderabad
# 7   B-25602  01-04-2018          NaN       Maharashtra                Pune
# 8   B-25858  13-11-2018          NaN       Maharashtra              Mumbai
# 9   B-25969  21-01-2018          NaN           Gujarat               Surat
# 10  B-26099  30-03-2018       Bhishm       Maharashtra              Mumbai
# ...

# %%
#How to make Order ID column as index column 
Data = pd.read_csv('C:\\Users\\user\\Desktop\\Assignment\\Orders.csv', index_col = 'Order ID')
Data
# Out:
#           Order Date CustomerName             State                City
# Order ID
# B-26055   10-03-2018    Harivansh     Uttar Pradesh             Mathura
# B-25993   03-02-2018       Madhav             Delhi               Delhi
# NaN       24-01-2018  Madan Mohan     Uttar Pradesh             Mathura
# NaN       27-12-2018        Gopal       Maharashtra              Mumbai
# B-25757   21-08-2018     Vishakha    Madhya Pradesh              Indore
# B-25967   21-01-2018       Sudevi     Uttar Pradesh                 NaN
# B-25955   16-01-2018        Shiva       Maharashtra                Pune
# B-26093   27-03-2018       Sarita       Maharashtra                Pune
# B-25798   01-10-2018       Shishu    Andhra Pradesh           Hyderabad
# B-25602   01-04-2018          NaN       Maharashtra                Pune
# B-25858   13-11-2018          NaN       Maharashtra              Mumbai
# B-25969   21-01-2018          NaN           Gujarat               Surat
# ...
